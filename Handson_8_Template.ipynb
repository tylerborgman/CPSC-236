# %% [markdown]
# # Strings
#
# To submit this assignment in D2l, post the link to your notebook file on your GitHub account.

# %% [markdown]
# ## 10.1 Email Creator
# Create a program that reads a file and creates a series of emails.
#
# ### Console:
# ```powershell
# Email Creator
#
# ================================================================
# To: jbutler@gmail.com
# From: noreply@deals.com
# Subject: Deals!
#
# Hi James,
#
# We've got some great deals for you. Check our website!
# ================================================================
# To:	josephine_darakjy@darakjy.org
# From:	noreply@deals.com
# Subject: Deals!
#
# Hi Josephine,
#
# We've got some great deals for you. Check our website!
# ================================================================
# To:	art@venere.org
# From:	noreply@deals.com
# Subject: Deals!
#
# Hi Art,
#
# We've got some great deals for you. Check our website!
# ```
#
# ### Specifications:
# - Use `email.csv` file:
# - Use `email_template.txt` file:
# - When the program starts, it should read the email addresses and first names from the file, merge them into the mass email template, and display the results on the console.
# - All email addresses should be converted to **lowercase**.
# - All first names should be converted to **title case**.
# - If you add names to the list of email addresses, the program should create more emails.
# - If you modify the template, the program should change the content of the email that’s created.

# %%
### CODE HERE ###
import csv

def read_csv(file_path):
    emails = []
    with open(file_path, 'r') as file:
        reader = csv.reader(file)
        for row in reader:
            if len(row) >= 3:  # Ensure each row has at least three elements
                first_name, last_name, email_address = row[0], row[1], row[2]
                full_name = f"{first_name.strip().title()} {last_name.strip().title()}"
                emails.append((email_address.strip().lower(), full_name))  # Convert email to lowercase
            else:
                print(f"Issue with row: {row}. Skipping...")
    return emails

def create_email(template_path, recipient, sender):
    try:
        with open(template_path, 'r') as file:
            template = file.read()
            email = template.format(email=recipient, first_name=recipient.split('@')[0].title(), sender=sender)
        return email
    except KeyError:
        print("Error: Template file does not contain necessary placeholders {email} and {first_name}.")
        return ""

def main():
    emails = read_csv('email.csv')
    template_path = 'email_template.txt'
    sender = 'noreply@deals.com'
    
    for email in emails:
        recipient_email, recipient_name = email
        email_content = create_email(template_path, recipient_email, sender)
        if email_content:
            print(email_content)
            print("=" * 64)

if __name__ == "__main__":
    print("Email Creator\n")
    print("=" * 64)
    main()
# Out:
# Email Creator
#
# ================================================================
# To:      jbutt@gmail.com
# From:    noreply@deals.com
# Subject: Deals!
#
# Hi Jbutt,
#
# We've got some great deals for you. Check our website!
# ================================================================
# To:      josephine_darakjy@darakjy.org
# From:    noreply@deals.com
# Subject: Deals!
#
# Hi Josephine_Darakjy,
#
# We've got some great deals for you. Check our website!
# ================================================================
# To:      art@venere.org
# From:    noreply@deals.com
# Subject: Deals!
#
# Hi Art,
#
# We've got some great deals for you. Check our website!
# ================================================================

# %% [markdown]
# ## 10.2 Pig Latin Translator
#
# Create a program that translates English to Pig Latin.
#
# ### Console:
# ```powershell
# Pig Latin Translator
#
# Enter text: Tis but a scratch.
# English:	tis but a scratch
# Pig Latin:	istay utbay away atchscray
#
# Continue? (y/n): y
#
# Enter text: We are the knights who say nee!
# English:	we are the knights who say nee
# Pig Latin:	eway areway ethay ightsknay owhay aysay eenay
#
# Continue? (y/n): n
#
# Bye!
# ```
#
# ### Specifications:
# - Convert the English to lowercase before translating.
# - Remove the following punctuation characters before translating `! , ; : - . ?`
# - Assume that words are separated from each other by a single space.
# - If the word starts with a vowel, just add *way* to the end of the word.
# - If the word starts with a consonant, move all of the consonants that appear before the first vowel to the end of the word, then add *ay* to the end of the word.
#
# ### Note:
# - There are no official rules for Pig Latin. Most people agree on how words that begin with consonants are translated, but there are many different ways to handle words that begin with vowels.

# %%
### CODE HERE ###
def translate_to_pig_latin(text):
    vowels = 'aeiou'
    punctuation = '!,:-.?'
    pig_latin_words = []

    for word in text.split():
        # Remove punctuation
        word = ''.join(char for char in word if char not in punctuation)
        # Convert word to lowercase
        word = word.lower()

        if word[0] in vowels:
            # Word starts with a vowel
            pig_latin_word = word + 'way'
        else:
            # Word starts with a consonant
            first_vowel_index = next((i for i, char in enumerate(word) if char in vowels), None)
            if first_vowel_index is not None:
                pig_latin_word = word[first_vowel_index:] + word[:first_vowel_index] + 'ay'
            else:
                # No vowels found, treat as if it starts with a vowel
                pig_latin_word = word + 'way'
        pig_latin_words.append(pig_latin_word)

    return ' '.join(pig_latin_words)

def main():
    print("Pig Latin Translator\n")
    while True:
        text = input("Enter text: ")
        english_text = text
        # Translate text to Pig Latin
        pig_latin_text = translate_to_pig_latin(text)
        
        print("English:   ", english_text)
        print("Pig Latin: ", pig_latin_text)
        
        choice = input("\nContinue? (y/n): ").strip().lower()
        if choice != 'y':
            print("\nBye!")
            break

if __name__ == "__main__":
    main()
# Out:
# Pig Latin Translator
#
# Enter text: Tis but a scratch
# English:    Tis but a scratch
# Pig Latin:  istay utbay away atchscray
#
# Continue? (y/n): y
# Enter text: We are the knights who say nee!
# English:    We are the knights who say nee!
# Pig Latin:  eway areway ethay ightsknay owhay aysay eenay
#
# Continue? (y/n): n
#
# Bye!
